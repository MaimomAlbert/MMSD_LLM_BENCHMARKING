# %% [markdown]
# ### Data Analysis on MMSD (OSINT)
# Contents:
# - Label consistency and agreement analysis
#     - Inter-Model Agreement Metrics
#     - Agreement distribution histogram

# %%
import pandas as pd

df = pd.read_csv("/Users/sinngamkhaidem/Developer/mllm-based-mmsd-osint/mllm_finetune/gpt_predictions/batch_1_2_3.csv")

# %%
df.columns
# Out:
# Index(['image_id', 'text', 'subreddit', 'llama32_11B', 'intervl25_8B',
#        'llava16_mistral_7B', 'llava16_vicuna_7B', 'idefics2_9B', 'num_models',
#        'major_label', 'exact_label'],
#       dtype='object')

# %% [markdown]
# ### Inter-Model Agreement Metrics
# Let us compute the Fleiss' Kappa for the 5 models
