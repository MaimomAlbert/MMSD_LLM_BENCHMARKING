# %%
import pandas as pd

df1 = pd.read_json("gpt_predictions/llama32_11B_osint.json")
df2 = pd.read_json("gpt_predictions/internvl25_osint.json")
df3 = pd.read_json("gpt_predictions/llava16_mistral_osint.json")
df4 = pd.read_json("gpt_predictions/llava16_vicuna_osint.json")
df5 = pd.read_json("gpt_predictions/idefics2_9B_osint.json")
# Out:
# Running cells with 'reddit_collection (Python 3.10.0)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
